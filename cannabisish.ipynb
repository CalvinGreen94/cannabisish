# %%
test_strains = 6  
print('Total strain {}'.format(test_strains))
total_tests= 226 
indica_tests = 11 
print('Total test {}'.format(total_tests))
train_test = total_tests - test_strains 
print('Total indica test {}'.format(indica_tests))
print('Train size {}'.format(train_test))
thc = 18.10 
thca = 13.65 
cbd = 1.17 
cbg = 0.65
thcv = 0.61 
cbc = 0.34
cbn = 0.11 

thc_indica = thc - .47  
thca_indica = thca - .57 
cbd_indica = cbd + .7
cbg_indica = cbg + .04
thcv_indica = thcv -.04 
cbc_indica = cbc + .10
cbn_indica = cbn - .04
print('THC average {}'.format(thc))
print('THC indica benchmark {}'.format(thc_indica))
print('THCA average {}'.format(thca))
print('THCA indica benchmark {}'.format(thca_indica))
print('CBD average {}'.format(cbd))
print('CBD indica benchmark {}'.format(cbd_indica))
print('CBG average {}'.format(cbg))
print('CBG indica benchmark {}'.format(cbg_indica))
print('THCV average {}'.format(thcv))
print('THCV indica benchmark {}'.format(thcv_indica))
print('CBC average {}'.format(cbc))
print('CBC indica benchmark {}'.format(cbc_indica))
print('CBN average {}'.format(cbn))
print('CBN indica benchmark {}'.format(cbn_indica))
# Out:
# Total strain 6
# Total test 226
# Total indica test 11
# Train size 220
# THC average 18.1
# THC indica benchmark 17.63
# THCA average 13.65
# THCA indica benchmark 13.08
# CBD average 1.17
# CBD indica benchmark 1.87
# CBG average 0.65
# CBG indica benchmark 0.69
# THCV average 0.61
# THCV indica benchmark 0.57
# CBC average 0.34
# CBC indica benchmark 0.44
# CBN average 0.11
# CBN indica benchmark 0.07

# %%
test_strains = 31
print('Total strain {}'.format(test_strains))
total_tests= 226 
print('Total test {}'.format(total_tests))
mostly_indica_tests = 80
train_test = total_tests - test_strains 
print('Train size {}'.format(train_test))
thc_mostly_indica = thc + .33
thca_mostly_indica = thca  + .77
cbd_mostly_indica = cbd -.87
cbg_mostly_indica = cbg +.01
thcv_mostly_indica = thcv -.04 
cbc_mostly_indica = cbc -.04
cbn_mostly_indica = cbn - .09
all = ['cbn +/-','thc +/-','thca +/-','cbg +/-','cbd +/-','cbc +/-']

thcc = all[1] 
thcaa = all[2] 
cbgg = all[3]
cbdd = all[4]  
cbcc = all[5] 
print('THC average {}'.format(thc))
print('THC mostly indica benchmark {}'.format(thc_mostly_indica))
print('THCA average {}'.format(thca))
print('THCA mostly indica benchmark {}'.format(thca_mostly_indica))
print('CBD average {}'.format(cbd))
print('CBD mostly indica benchmark {}'.format(cbd_mostly_indica))
print('CBG average {}'.format(cbg))
print('CBG mostly indica benchmark'.format(cbg_mostly_indica))
print('THCV average {}'.format(thcv))
print('THCV mostly indica benchmark'.format(thcv_mostly_indica))
print('CBC average {}'.format(cbc))
print('CBC mostly indica benchmark'.format(cbc_mostly_indica))
print('CBN average {}'.format(cbn))
print('CBN mostly indica benchmark {}'.format(cbn_mostly_indica))
# Out:
# Total strain 31
# Total test 226
# Train size 195
# THC average 18.1
# THC mostly indica benchmark 18.43
# THCA average 13.65
# THCA mostly indica benchmark 14.42
# CBD average 1.17
# CBD mostly indica benchmark 0.3
# CBG average 0.65
# CBG mostly indica benchmark
# THCV average 0.61
# THCV mostly indica benchmark
# CBC average 0.34
# CBC mostly indica benchmark
# CBN average 0.11
# CBN mostly indica benchmark 0.02

# %%
test_strains = 16
print('Total strain {}'.format(test_strains))
total_tests= 226 
print('Total test {}'.format(total_tests))
train_test = total_tests - test_strains 
print('Train size {}'.format(train_test)) 
total_hybrid_test = 31 
thc_hybrid = thc - 1.09
thca_hybrid = thca  +1.00
cbd_hybrid = cbd + 1.61
cbg_hybrid = cbg - .14
thcv_hybrid = thcv -.03
cbc_hybrid = cbc -.04
cbn_hybrid = cbn - .10
print('THC average {}'.format(thc))
print('THC hybrid benchmark {}'.format(thc_hybrid))
print('THCA average {}'.format(thca))
print('THCA hybrid benchmark {}'.format(thca_hybrid))
print('CBD average {}'.format(cbd))
print('CBD hybrid benchmark {}'.format(cbd_hybrid))
print('CBG average {}'.format(cbg))
print('CBG hybrid benchmark'.format(cbg_hybrid))
print('THCV average {}'.format(thcv))
print('THCV hybrid benchmark'.format(thcv_hybrid))
print('CBC average {}'.format(cbc))
print('CBC hybrid benchmark'.format(cbc_hybrid))
print('CBN average {}'.format(cbn))
print('CBN hybrid benchmark {}'.format(cbn_hybrid))
# Out:
# Total strain 16
# Total test 226
# Train size 210
# THC average 18.1
# THC hybrid benchmark 17.01
# THCA average 13.65
# THCA hybrid benchmark 14.65
# CBD average 1.17
# CBD hybrid benchmark 2.78
# CBG average 0.65
# CBG hybrid benchmark
# THCV average 0.61
# THCV hybrid benchmark
# CBC average 0.34
# CBC hybrid benchmark
# CBN average 0.11
# CBN hybrid benchmark 0.01

# %%
test_strains = 31 
print('Total strain {}'.format(test_strains))
total_tests= 226 
print('Total test {}'.format(total_tests))
train_test = total_tests - test_strains 
print('Train size {}'.format(train_test))
total_sativa_tests = 98 
thc_sativa= thc + .59
thca_sativa= thca - .62
cbd_sativa= cbd - .03
cbg_sativa= cbg - 0.00
thcv_sativa= thcv + .08
cbc_sativa= cbc + .02
cbn_sativa= cbn - .09
print('THC average {}'.format(thc))
print('THC sativabenchmark {}'.format(thc_hybrid))
print('THCA average {}'.format(thca))
print('THCA sativabenchmark {}'.format(thca_hybrid))
print('CBD average {}'.format(cbd))
print('CBD sativabenchmark {}'.format(cbd_hybrid))
print('CBG average {}'.format(cbg))
print('CBG sativabenchmark'.format(cbg_hybrid))
print('THCV average {}'.format(thcv))
print('THCV sativabenchmark'.format(thcv_hybrid))
print('CBC average {}'.format(cbc))
print('CBC sativabenchmark'.format(cbc_hybrid))
print('CBN average {}'.format(cbn))
print('CBN sativabenchmark {}'.format(cbn_hybrid))
# Out:
# Total strain 31
# Total test 226
# Train size 195
# THC average 18.1
# THC sativabenchmark 17.01
# THCA average 13.65
# THCA sativabenchmark 14.65
# CBD average 1.17
# CBD sativabenchmark 2.78
# CBG average 0.65
# CBG sativabenchmark
# THCV average 0.61
# THCV sativabenchmark
# CBC average 0.34
# CBC sativabenchmark
# CBN average 0.11
# CBN sativabenchmark 0.01

# %%
import pandas as pd 

all_indica = ['cbn +/-','thc +/-','thca +/-','cbg +/-','cbd +/-','cbc +/-','thcv +/-']
cbnn = all_indica[0]
thcc = all_indica[1] 
thcaa = all_indica[2] 
cbgg = all_indica[3]
cbdd = all_indica[4]  
cbcc = all_indica[5]
thcvv = all_indica[6]

# %%
mostly_indica ={'thc': [thc_mostly_indica],'thca':[thca_mostly_indica],'thcv':[thcv_mostly_indica],
           'cbd': [cbd_mostly_indica],'cbg':[cbg_mostly_indica],
           'cbc': [cbc_mostly_indica], 'cbn': [cbn_mostly_indica],thcc:[.33],cbnn:[-.09],cbcc:[-.04],cbdd:[-.87],thcaa:[.77],cbgg:[.01],thcvv:[-.04],
                'ind/ind.dom/sat/sat.dom/hybrid':['ind_dom'],'ind/ind.dom/sat/sat.dom/hybrid_label':['ind_dom']} 
mostly_indica = pd.DataFrame(data=mostly_indica,index=[3])

hybrid = {'thc': [thc_hybrid],'thca':[thca_hybrid],'thcv':[thcv_hybrid],
           'cbd': [cbd_hybrid],'cbg':[cbg_hybrid],thcc:[-1.09],cbnn:[-.1],cbcc:[-.04],cbdd:[1.61],thcaa:[.57],cbgg:[-.14],thcvv:[-.03],
           'cbc': [cbc_hybrid], 'cbn': [cbn_hybrid],
          'ind/ind.dom/sat/sat.dom/hybrid':['hybrid'],'ind/ind.dom/sat/sat.dom/hybrid_label':['hybrid']} 
hybrid = pd.DataFrame(data=hybrid,index=[2])
hybrid = hybrid.append(mostly_indica)

sativa = {'thc': [thc_sativa],'thca':[thca_sativa],
           'cbd': [cbd_sativa],'cbg':[cbg_sativa],thcc:[.59],cbnn:[-.09],cbcc:[.02],cbdd:[-.03],thcaa:[-.62],cbgg:[.00],thcvv:[.08],
           'cbc': [cbc_sativa], 'cbn': [cbn_sativa],'thcv':[thcv_sativa],
          'ind/ind.dom/sat/sat.dom/hybrid':['sativa'],'ind/ind.dom/sat/sat.dom/hybrid_label':['sativa']} 
sativa = pd.DataFrame(data=sativa,index=[1])
sativa = sativa.append(hybrid) 

indica = {
          'thc': [thc_indica],'thca':[thca_indica],'thcv':[thcv_indica],
           'cbd': [cbd_indica],'cbg':[cbg_indica],thcc:[.47],cbnn:[-.04],cbcc:[.1],cbdd:[.7],thcaa:[.57],cbgg:[.01],thcvv:[-.04],
           'cbc': [cbc_indica], 'cbn': [cbn_indica],
          'ind/ind.dom/sat/sat.dom/hybrid':['indica'],'ind/ind.dom/sat/sat.dom/hybrid_label':['indica']} 
indica = pd.DataFrame(data=indica,index=[0])
indica = indica.append(sativa)
indica['ind/ind.dom/sat/sat.dom/hybrid_label'] =indica['ind/ind.dom/sat/sat.dom/hybrid_label'].str.replace('indica', '0') 
indica['ind/ind.dom/sat/sat.dom/hybrid_label'] =indica['ind/ind.dom/sat/sat.dom/hybrid_label'].str.replace('ind_dom', '1')
indica['ind/ind.dom/sat/sat.dom/hybrid_label'] =indica['ind/ind.dom/sat/sat.dom/hybrid_label'].str.replace('hybrid', '2')
indica['ind/ind.dom/sat/sat.dom/hybrid_label'] =indica['ind/ind.dom/sat/sat.dom/hybrid_label'].str.replace('sativa', '3')
data = indica

# %%
data
# Out:
#     cbc  cbc +/-   cbd  cbd +/-   cbg  cbg +/-   cbn  cbn +/-  \
# 0  0.44     0.10  1.87     0.70  0.69     0.01  0.07    -0.04
# 1  0.36     0.02  1.14    -0.03  0.65     0.00  0.02    -0.09
# 2  0.30    -0.04  2.78     1.61  0.51    -0.14  0.01    -0.10
# 3  0.30    -0.04  0.30    -0.87  0.66     0.01  0.02    -0.09
#
#   ind/ind.dom/sat/sat.dom/hybrid ind/ind.dom/sat/sat.dom/hybrid_label    thc  \
# 0                         indica                                    0  17.63
# 1                         sativa                                    3  18.69
# 2                         hybrid                                    2  17.01
# 3                        ind_dom                                    1  18.43
#
#    thc +/-   thca  thca +/-  thcv  thcv +/-
# 0     0.47  13.08      0.57  0.57     -0.04
# 1     0.59  13.03     -0.62  0.69      0.08
# 2    -1.09  14.65      0.57  0.58     -0.03
# 3     0.33  14.42      0.77  0.57     -0.04

# %%
Sour Diesel
Moon Rock
GrandDaddy 
Purple
OG Kush
Sour OG Kush
Green Crack
Jack Dream
AK-47
Purple Kush
Bubba Kush
 Bubblegum Kush
Blueberry
Gelato
Purple-Skunk
 Master Kush
Purple Haze
Banana Kush
pineapple express
 Orange kush
Night Queen
Big Bud
Cheese
BlueDream
White Russia
White Widow
G13…
Lemon haze
Golden state banana
Ak47
Purple urkle 
Dream land
Train wreck
Lemon bubble 
Skittles
Cherry OG 
Banana punch
Golden gorilla 
Supreme punch 
Yoga OG
Goshers 
Fire OG 
Strawberry pie
Boss OG
Strawberry shortcake 
Mimosa 
Lemonade 
Apple fritter 
GSC

# %%
def strain(strain):
    indica = ['g13', 'northern lights','granddaddy purple','purple kush','bubba kush','bubblegum kush','blueberry','lemonade'
             'master kush','orange kush','night queen','big bud','golden state banana','purple urkle','yoda og','zkittles','cherry og']
    sativa = ['alaskan thunderfuck','sour diesel','green crack','moon rock','purple skunk','purple haze','lemon haze','dream band',
             'lemon bubble','golden gorilla','strawberry shortcake','mimosa','girl scout cookies']
    hybrid = ['og kush','sour og kush','jacks dream','AK-47','gelato','banana kush','pineapple express','cheese','blue dream',
             'white russian','white widow','trainwreck','banana punch','supreme punch','gushers','fire og','strawberry pie',
              'boss og','apple fritter']

    import webbrowser
    strain = strain
    if strain in indica:
        print('okay {}'.format(str(strain)))
        print('This strain is an indica')        
        print('the following data provides insights into the strains molecular makeup')
        indica = data.drop(['ind/ind.dom/sat/sat.dom/hybrid'],axis=1)
        indica = indica.drop('ind/ind.dom/sat/sat.dom/hybrid_label',axis=1)
        indica = indica[:1]
        indica = pd.DataFrame(indica)
        return indica 
    elif strain in sativa:
        print('okay {}'.format(str(strain)))
        print('This strain is a sativa')        
        print('the following data provides insights into the strains molecular makeup')
        sativa = data.drop(['ind/ind.dom/sat/sat.dom/hybrid'],axis=1)
        sativa = sativa.drop('ind/ind.dom/sat/sat.dom/hybrid_label',axis=1)
        sativa = sativa[1:2]
        sativa = pd.DataFrame(sativa)
        print('taking you to the item page now')
        if strain == 'green crack':
            green_purchase = webbrowser.open('https://sales.cannabissolutions.icu/product/green-crack-2/') 
            green_purchase       
        return sativa
    elif strain in hybrid:
        print('okay {}'.format(str(strain)))
        print('This strain is a sativa')        
        print('the following data provides insights into the strains molecular makeup')
        hybrid = data.drop(['ind/ind.dom/sat/sat.dom/hybrid'],axis=1)
        hybrid = hybrid.drop('ind/ind.dom/sat/sat.dom/hybrid_label',axis=1)
        hybrid = hybrid[2:3]
        hybrid = pd.DataFrame(hybrid)
        print('taking you to the item page now')
        return hybrid
    else:
        print('strain not found taking you to product page') 
        web = webbrowser.open('https://sales.cannabissolutions.icu/products/')

    
    
    return 
strain('g13')
# Out:
# okay g13
# This strain is an indica
# the following data provides insights into the strains molecular makeup
#     cbc  cbc +/-   cbd  cbd +/-   cbg  cbg +/-   cbn  cbn +/-    thc  thc +/-  \
# 0  0.44      0.1  1.87      0.7  0.69     0.01  0.07    -0.04  17.63     0.47
#
#     thca  thca +/-  thcv  thcv +/-
# 0  13.08      0.57  0.57     -0.04

# %%
data.describe()
# Out:
#             cbc   cbc +/-     cbd  cbd +/-       cbg   cbg +/-      cbn  \
# count  4.000000  4.000000  4.0000   4.0000  4.000000  4.000000  4.00000
# mean   0.350000  0.010000  1.5225   0.3525  0.627500 -0.030000  0.03000
# std    0.066332  0.066332  1.0556   1.0556  0.080156  0.073485  0.02708
# min    0.300000 -0.040000  0.3000  -0.8700  0.510000 -0.140000  0.01000
# 25%    0.300000 -0.040000  0.9300  -0.2400  0.615000 -0.035000  0.01750
# 50%    0.330000 -0.010000  1.5050   0.3350  0.655000  0.005000  0.02000
# 75%    0.380000  0.040000  2.0975   0.9275  0.667500  0.010000  0.03250
# max    0.440000  0.100000  2.7800   1.6100  0.690000  0.010000  0.07000
#
#        cbn +/-        thc   thc +/-       thca  thca +/-      thcv  thcv +/-
# count  4.00000   4.000000  4.000000   4.000000  4.000000  4.000000  4.000000
# mean  -0.08000  17.940000  0.075000  13.795000  0.322500  0.602500 -0.007500
# std    0.02708   0.766725  0.783901   0.859864  0.635367  0.058523  0.058523
# ...

# %%
corr = data.corr()
# Out:
#                cbc   cbc +/-       cbd   cbd +/-       cbg   cbg +/-  \
# cbc       1.000000  1.000000  0.122345  0.122345  0.633195  0.506043
# cbc +/-   1.000000  1.000000  0.122345  0.122345  0.633195  0.506043
# cbd       0.122345  0.122345  1.000000  1.000000 -0.686953 -0.794117
# cbd +/-   0.122345  0.122345  1.000000  1.000000 -0.686953 -0.794117
# cbg       0.633195  0.633195 -0.686953 -0.686953  1.000000  0.984679
# cbg +/-   0.506043  0.506043 -0.794117 -0.794117  0.984679  1.000000
# cbn       0.927837  0.927837  0.055972  0.055972  0.660328  0.519270
# cbn +/-   0.927837  0.927837  0.055972  0.055972  0.660328  0.519270
# thc       0.010487  0.010487 -0.890874 -0.890874  0.665499  0.780938
# thc +/-   0.552585  0.552585 -0.739771 -0.739771  0.962583  0.981402
# thca     -0.853248 -0.853248  0.130462  0.130462 -0.686995 -0.636208
# thca +/- -0.173209 -0.173209  0.104705  0.104705 -0.132702 -0.197759
# thcv      0.060106  0.060106 -0.179812 -0.179812  0.108363  0.193772
# ...

# %%
indica = data['ind/ind.dom/sat/sat.dom/hybrid'][0]
sativa = data['ind/ind.dom/sat/sat.dom/hybrid'][1]
hybrid = data['ind/ind.dom/sat/sat.dom/hybrid'][2]
indica_dom = data['ind/ind.dom/sat/sat.dom/hybrid'][3]
import matplotlib.pyplot as plt
# Out:
# n

# %%
X = data['thc'] + data['thc +/-']
X.hist()
# Out:
# 0    18.10
# 1    19.28
# 2    15.92
# 3    18.76
# dtype: float64

# %%
y = data.drop(['thc'],axis=1)
y.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010367B38>,
# ...
#       dtype=object)

# %%
plt.scatter(data['cbc'],data['cbc +/-'])
plt.scatter(data['cbn'],data['cbn +/-'])
plt.scatter(data['thc'],data['thc +/-'])
plt.scatter(data['thca'],data['thca +/-'])
plt.scatter(data['cbd'],data['cbd +/-'])
plt.scatter(data['thcv'],data['thcv +/-'])

# %%
import matplotlib.pyplot as plt 
def optimize_price(initial_investment,per_category_investment,inventory,i_pay,mean,customer_buys):
    inital_investment = initial_investment
    per_category_investment = per_category_investment 
    print('INVESTED IN EACH OF THE 10 CATEGORIES ${:.2f}'.format(per_category_investment))
    mean = mean 
    i_pay = i_pay
    num_categories = 10
    invent = i_pay *inventory
    current_spend = inital_investment  - per_category_investment
    print('UNUSED FUNDS: {}'.format(current_spend))
    
    profit_target = (current_spend *1.5)/26 #biweekly .....___--rajfdlka(current_spend*1.5)
    returns = profit_target/current_spend
    new_price = mean*returns+i_pay
    price_range = mean-new_price
    print('THE PRICE RANGE WIL HELP UP TO FIND THE PERFECT PRICE FOR MAXIMUM RETURNS AND MANAGE LOSSES.')
    optimal_price = mean - price_range
    print('IF I PAY ${:.2f} PER ITEM , AND MY STARTING INVESTMENT IS: ${:.2f} \nWITH AN INVENTORY OF: {} ITEMS AT AN AVERAGE PRICE OF ${:.2f}'.format(i_pay,inital_investment,inventory,mean))
    print('WE WILL WANT A PROFIT TARGET OF: ${:.2f} BIWEEKLY FOR A 1.5 PERCENT RETURN, \nMY RETURNS WILL BE: ${:.2f} PER DOLLAR \nWHILE THE ITEM WILL HAVE A NEW PRICE OF: ${:.2f} \nWITH A PRICE RANGE OF: {:.2f}'.format(profit_target,returns,new_price,price_range))
    print('OPTIMAL PRICE: ${:.2f}'.format(optimal_price))
#     print('PROFIT IF STRATEGY FOLLWED WILL BE: ${:.2f} \nFOR ITEMS IN EACH OF THE TEN CATEGORIES THAT COST: ${}'.format(returns*,mean))
#     print('ANNUAL PROFIT: {:.2f}'.format(inital_investment*returns*26))
    cus_buys = customer_buys
    customer_buys = customer_buys * optimal_price
    company_backorder = 0 
    back_order = company_backorder
    in_stock = True 
    amount_in_stock = inventory - cus_buys
    if customer_buys >= profit_target:
        print('THE CUSTOMER BOUGHT {} ITEMS'.format(cus_buys))
        print('SINCE THE CUSTOMER BOUGHT THIS AMOUNT OF ITEMS YOU ARE ${:.2f} ABOVE THE PROFIT TARGET'.format(customer_buys-profit_target))
        print('CONGRATULATIONS YOU REACHED THE BIWEEKLY PROFIT TARGET ${:.2f}'.format(customer_buys+returns))
        can_buy = (customer_buys + returns)/cus_buys
        print('YOU CAN BUY {} ITEMS AT WHOLESALE PRICE OF ${:.2f}'.format(can_buy,i_pay))
        print('YOU GAINED A PROFIT OF ${:.2f} AFTER THE PURCHASE OF {} ITEMS'.format(customer_buys*returns,cus_buys))
        if amount_in_stock == company_backorder:
            print('CANNOT FULFILL ORDER , OUT OF STOCK BY {} AMOUNT'.format(amount_in_stock))
        if amount_in_stock == back_order:
            print('CANNOT ORDER THE COMPANY HAS BACK-ORDERS OF {} ITEMS IN STOCK FOR THIS ITEM'.format(back_order))
        if amount_in_stock <= cus_buys:
            print(' SORRY BUT THIS ORDER CANNOT BE FULFILLED.. OUT OF INVENTORY DOES THE PARENT COMPANY HAVE ANY IN STOCK')
#         if amount_in_stock <=13 and amount_in_stock >= amount_in_stock:
#             print('ITEMS HAVE A DISCOUNTED PRICE OF ${:.2f}'.format(-price_range))            
        else:
            print('ORDER FULFILLED {} ITEMS IN STOCK'.format(amount_in_stock))
        plt.hist(profit_target) 
#     plt.scatter(customer_buys,optimal_price,price_range,new_price)
        plt.hist(customer_buys)
    elif customer_buys <= profit_target:
        print('THE CUSTOMER BOUGHT {} ITEMS'.format(cus_buys))
        print('SINCE THE CUSTOMER BOUGHT THIS AMOUNT OF ITEMS YOU ARE ${:.2f} AWAY FROM THE PROFIT TARGET  OF ${:.2f}'.format(profit_target-customer_buys,profit_target))
        print('PROFIT TARGET NOT YET HIT')
        can_buy =(customer_buys +returns)/cus_buys
        print('YOU CAN BUY {} ITEMS AT WHOLESALE PRICE OF ${:.2f}'.format(can_buy,i_pay))
        print('YOU GAINED A PROFIT OF ${:.2f} AFTER THE PURCHASE OF {} ITEMS'.format(customer_buys*returns,cus_buys))
        if amount_in_stock == 0:
            print('CANNOT FULFILL ORDER , OUT OF STOCK BY {} AMOUNT'.format(amount_in_stock))
        else:
            print('ORDER FULFILLED {} ITEMS IN STOCK'.format(amount_in_stock)) 
        if amount_in_stock <=5 and amount_in_stock >= amount_in_stock:
            print('ITEMS HAVE A DISCOUNTED PRICE OF ${:.2f}'.format(price_range))
        plt.hist(profit_target)
#     plt.scatter(customer_buys,optimal_price,price_range,new_price)
        plt.hist(customer_buys)
        
    return #i_pay,mean,current_spend,profit_target,returns,new_price
